# %% [markdown]
# # Interactive Examples on Project Aria Tools
#
# ### Notebook stuck?
# Note that because of Jupyter issues, sometimes the code may stuck at visualization. We recommend **restart the kernels** and try again to see if the issue is resolved.

# %%
# Specifics for Google Colab
google_colab_env = 'google.colab' in str(get_ipython())
if google_colab_env:
    print("Running from Google Colab, installing projectaria_tools and getting sample data")
    # !pip install projectaria-tools
    # !curl -O -J -L "https://github.com/facebookresearch/projectaria_tools/raw/main/data/mps_sample/sample.vrs"
    vrsfile = "sample.vrs"
else:
    print("Using a pre-existing projectaria_tool github repository")
    vrsfile = "../../data/mps_sample/sample.vrs"
# Out:
# Using a pre-existing projectaria_tool github repository

# %%
from projectaria_tools.core import data_provider, calibration
from projectaria_tools.core.image import InterpolationMethod
from projectaria_tools.core.sensor_data import TimeDomain, TimeQueryOptions
from projectaria_tools.core.stream_id import RecordableTypeId, StreamId
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Create data provider

# %%
print(f"Creating data provider from {vrsfile}")
provider = data_provider.create_vrs_data_provider(vrsfile)
if not provider:
    print("Invalid vrs data provider")
# Out:
# Creating data provider from ../../data/mps_sample/sample.vrs
# [ProgressLogger][INFO]: 2024-11-27 14:13:10: Opening ../../data/mps_sample/sample.vrs...
# [MultiRecordFileReader][DEBUG]: Opened file '../../data/mps_sample/sample.vrs' and assigned to reader #0
# [VrsDataProvider][INFO]: streamId 211-1/camera-et activated
# [VrsDataProvider][INFO]: streamId 214-1/camera-rgb activated
# [VrsDataProvider][INFO]: streamId 231-1/mic activated
# [VrsDataProvider][INFO]: streamId 247-1/baro0 activated
# [VrsDataProvider][INFO]: streamId 281-1/gps activated
# [VrsDataProvider][INFO]: streamId 282-1/wps activated
# [VrsDataProvider][INFO]: streamId 283-1/bluetooth activated
# [VrsDataProvider][WARNING]: Unsupported TimeSync mode: APP, ignoring.
# [VrsDataProvider][INFO]: streamId 1201-1/camera-slam-left activated
# [VrsDataProvider][INFO]: streamId 1201-2/camera-slam-right activated
# [VrsDataProvider][INFO]: streamId 1202-1/imu-right activated
# [VrsDataProvider][INFO]: streamId 1202-2/imu-left activated
# [VrsDataProvider][INFO]: streamId 1203-1/mag0 activated

# %% [markdown]
# # Retrieving image data
#
# Goals:
# - Learn how to retrieve Image data for a given Image stream
#
# Key learnings:
# - VRS contains data streams are identified with a Unique Identifier: stream_id
# - Learn what are the Stream Ids used by Aria data (Slam, Rgb, EyeTracking)
# - Learn that image data can be retrieved by using a record Index or a timestamp
# - For each stream_id, index ranges from [0, get_num_data(stream_id)], and the same index for different streams could have different timestamps
# - Query data from different sensors of the same timestamp can be done through `get_image_data_by_time_ns`, `get_imu_data_by_time_ns`, etc

# %%
stream_mappings = {
    "camera-slam-left": StreamId("1201-1"),
    "camera-slam-right":StreamId("1201-2"),
    "camera-rgb":StreamId("214-1"),
    "camera-eyetracking":StreamId("211-1"),
}

axes = []
fig, axes = plt.subplots(1, 4, figsize=(12, 5))
fig.suptitle('Retrieving image data using Record Index')

# Query data with index
frame_index = 1
for idx, [stream_name, stream_id] in enumerate(list(stream_mappings.items())):
    image = provider.get_image_data_by_index(stream_id, frame_index)
    axes[idx].imshow(image[0].to_numpy_array(), cmap="gray", vmin=0, vmax=255)
    axes[idx].title.set_text(stream_name)
    axes[idx].tick_params(left=False, right=False, labelleft=False, labelbottom=False, bottom=False)
plt.show()

# Same example using Time
rgb_stream_id = StreamId('214-1')
plt.figure()
fig, axes = plt.subplots(1, 4, figsize=(12, 5))
fig.suptitle('Retrieving image data using Time')

time_domain = TimeDomain.DEVICE_TIME  # query data based on host time
option = TimeQueryOptions.CLOSEST # get data whose time [in TimeDomain] is CLOSEST to query time
start_time = provider.get_first_time_ns(rgb_stream_id, time_domain)

for idx, [stream_name, stream_id] in enumerate(list(stream_mappings.items())):
    image = provider.get_image_data_by_time_ns(stream_id, start_time, time_domain, option)
    axes[idx].imshow(image[0].to_numpy_array(), cmap="gray", vmin=0, vmax=255)
    axes[idx].title.set_text(stream_name)
    axes[idx].tick_params(left=False, right=False, labelleft=False, labelbottom=False, bottom=False)
plt.show()

# %% [markdown]
# # Summarize a VRS using thumbnails
#
# Goals:
# - Summarize a VRS using 10 image side by side
#
# Key learnings:
# - Image streams are identified with a Unique Identifier: stream_id
# - PIL images can be created from Numpy array

# %%
from PIL import Image
from tqdm import tqdm

rgb_stream_id = StreamId("214-1")

# Retrieve Start and End time for the given Sensor Stream Id
start_time = provider.get_first_time_ns(rgb_stream_id, time_domain)
end_time = provider.get_last_time_ns(rgb_stream_id, time_domain)

# Retrieve image size for the RGB stream
time_domain = TimeDomain.DEVICE_TIME  # query data based on host time
option = TimeQueryOptions.CLOSEST # get data whose time [in TimeDomain] is CLOSEST to query time

image_config = provider.get_image_configuration(rgb_stream_id)
width = image_config.image_width
height = image_config.image_height

sample_count = 10
resize_ratio = 10
thumbnail = newImage = Image.new(
    "RGB", (int(width * sample_count / resize_ratio), int(height / resize_ratio))
)
current_width = 0


# Samples 10 timestamps
sample_timestamps = np.linspace(start_time, end_time, sample_count)
for sample in tqdm(sample_timestamps):
    image_tuple = provider.get_image_data_by_time_ns(rgb_stream_id, int(sample), time_domain, option)
    image_array = image_tuple[0].to_numpy_array()
    image = Image.fromarray(image_array)
    new_size = (
        int(image.size[0] / resize_ratio),
        int(image.size[1] / resize_ratio),
    )
    image = image.resize(new_size).rotate(-90)
    thumbnail.paste(image, (current_width, 0))
    current_width = int(current_width + width / resize_ratio)

from IPython.display import Image 
display(thumbnail)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 10/10 [00:00<00:00, 42.85it/s]
# <PIL.Image.Image image mode=RGB size=1408x140>

# %% [markdown]
# # Obtain mapping between stream_id and sensor label
# Goals:
# - In a vrs file, each sensor data is identified through stream_id
# - Learn mapping between stream_id and label for each sensor
#
# Key learnings:
# - VRS is using Unique Identifier for each stream called stream_id.
# - For each sensor data, it is attached with a stream_id, which contains two parts [RecordableTypeId, InstanceId].
# - To get the actual readable name of each sensor,
# we can use `get_label_from_stream_id` vise versa `get_stream_id_from_label`

# %%
streams = provider.get_all_streams()
for stream_id in streams:
    label = provider.get_label_from_stream_id(stream_id)
    print(
        f"stream_id: [{stream_id}] convert to label: [{label}] and back: [{provider.get_stream_id_from_label(label)}]"
    )
# Out:
# stream_id: [211-1] convert to label: [camera-et] and back: [211-1]
# stream_id: [214-1] convert to label: [camera-rgb] and back: [214-1]
# stream_id: [231-1] convert to label: [mic] and back: [231-1]
# stream_id: [247-1] convert to label: [baro0] and back: [247-1]
# stream_id: [281-1] convert to label: [gps] and back: [281-1]
# stream_id: [282-1] convert to label: [wps] and back: [282-1]
# stream_id: [283-1] convert to label: [bluetooth] and back: [283-1]
# stream_id: [1201-1] convert to label: [camera-slam-left] and back: [1201-1]
# stream_id: [1201-2] convert to label: [camera-slam-right] and back: [1201-2]
# stream_id: [1202-1] convert to label: [imu-right] and back: [1202-1]
# stream_id: [1202-2] convert to label: [imu-left] and back: [1202-2]
# stream_id: [1203-1] convert to label: [mag0] and back: [1203-1]

# %% [markdown]
# # Get sensor data in a sequence based on data capture time
# Goal:
# - Obtain sensor data sequentially based on timestamp
#
# Key learnings
# - Default option activates all sensors and playback the entire dataset from vrs
# - Setup option to only activate certain streams, truncate start/end time, and sample rate
# - Obtain data from different sensor types
# - `TimeDomain` are separated into four categories: `RECORD_TIME`, `DEVICE_TIME`, `HOST_TIME`, `TIME_CODE`

# %% [markdown]
# ### Step 1: obtain default options that provides the whole dataset from VRS
# * activates all sensor streams
# * No truncation for first/last timestamp
# * Subsample rate = 1 (do not skip any data per sensor)

# %%
options = (
    provider.get_default_deliver_queued_options()
)  # default options activates all streams

# %% [markdown]
# ### Step 2: set preferred deliver options
# * truncate first/last time: `set_truncate_first_device_time_ns/set_truncate_last_device_time_ns()`
# * subselect sensor streams to play: `activate_stream(stream_id)`
# * skip sensor data : `set_subsample_rate(stream_id, rate)`

# %%
options.set_truncate_first_device_time_ns(int(1e8))  # 0.1 secs after vrs first timestamp
options.set_truncate_last_device_time_ns(int(1e9))  # 1 sec before vrs last timestamp

# deactivate all sensors
options.deactivate_stream_all()
# activate only a subset of sensors
slam_stream_ids = options.get_stream_ids(RecordableTypeId.SLAM_CAMERA_DATA)
imu_stream_ids = options.get_stream_ids(RecordableTypeId.SLAM_IMU_DATA)

for stream_id in slam_stream_ids:
    options.activate_stream(stream_id)  # activate slam cameras
    options.set_subsample_rate(stream_id, 1)  # sample every data for each slam camera
    
for stream_id in imu_stream_ids:
    options.activate_stream(stream_id)  # activate imus
    options.set_subsample_rate(stream_id, 10)  # sample every 10th data for each imu

# %% [markdown]
# ### Step 3: create iterator to deliver data
# `TimeDomain` contains the following
# * `RECORD_TIME`: timestamp stored in vrs index, fast to access, but not guaranteed which time domain
# * `DEVICE_TIME`: capture time in device's timedomain, accurate
# * `HOST_TIME`: arrival time in host computer's timedomain, may not be accurate
# * `TIME_CODE`: capture in TimeSync server's timedomain

# %%
iterator = provider.deliver_queued_sensor_data(options)
for sensor_data in iterator:
    label = provider.get_label_from_stream_id(sensor_data.stream_id())
    sensor_type = sensor_data.sensor_data_type()
    device_timestamp = sensor_data.get_time_ns(TimeDomain.DEVICE_TIME)
    host_timestamp = sensor_data.get_time_ns(TimeDomain.HOST_TIME)
    timecode_timestamp = sensor_data.get_time_ns(TimeDomain.TIME_CODE)
    print(
        f"""obtain data from {label} of type {sensor_type} with \n
        DEVICE_TIME: {device_timestamp} nanoseconds \n
        HOST_TIME: {host_timestamp} nanoseconds \n
        """
    )
# Out:
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148514289987 nanoseconds
#
#         HOST_TIME: 148518608171 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148514884862 nanoseconds
#
#         HOST_TIME: 148519872077 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148524877262 nanoseconds
#
#         HOST_TIME: 148529515619 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148526898925 nanoseconds
#
#         HOST_TIME: 148530917494 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148534869737 nanoseconds
#
#         HOST_TIME: 148539875619 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148539507912 nanoseconds
#
#         HOST_TIME: 148544914213 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148544862012 nanoseconds
#
#         HOST_TIME: 148549831973 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148552116887 nanoseconds
#
#         HOST_TIME: 148556676088 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148554854537 nanoseconds
#
#         HOST_TIME: 148560122390 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148564725825 nanoseconds
#
#         HOST_TIME: 148570117182 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148564847175 nanoseconds
#
#         HOST_TIME: 148570135775 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148574839762 nanoseconds
#
#         HOST_TIME: 148579977286 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148577334812 nanoseconds
#
#         HOST_TIME: 148581689838 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148584832200 nanoseconds
#
#         HOST_TIME: 148589859317 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148589943787 nanoseconds
#
#         HOST_TIME: 148595054786 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148594824612 nanoseconds
#
#         HOST_TIME: 148598231557 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148602552725 nanoseconds
#
#         HOST_TIME: 148606799369 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148602610937 nanoseconds
#
#         HOST_TIME: 148614665973 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148602610950 nanoseconds
#
#         HOST_TIME: 148614666963 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148604817350 nanoseconds
#
#         HOST_TIME: 148611257702 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148614809750 nanoseconds
#
#         HOST_TIME: 148619450463 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148615161700 nanoseconds
#
#         HOST_TIME: 148619468744 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148624802325 nanoseconds
#
#         HOST_TIME: 148630077129 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148627770662 nanoseconds
#
#         HOST_TIME: 148631905150 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148634794650 nanoseconds
#
#         HOST_TIME: 148638573119 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148640379637 nanoseconds
#
#         HOST_TIME: 148645500411 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148644787350 nanoseconds
#
#         HOST_TIME: 148649132286 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148652988587 nanoseconds
#
#         HOST_TIME: 148657767806 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148654779962 nanoseconds
#
#         HOST_TIME: 148659271504 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148664772287 nanoseconds
#
#         HOST_TIME: 148669558223 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148665597550 nanoseconds
#
#         HOST_TIME: 148669588952 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148674764900 nanoseconds
#
#         HOST_TIME: 148679632598 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148678206512 nanoseconds
#
#         HOST_TIME: 148683876504 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148684757462 nanoseconds
#
#         HOST_TIME: 148688929890 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148690815487 nanoseconds
#
#         HOST_TIME: 148695803588 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148694750000 nanoseconds
#
#         HOST_TIME: 148700492859 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148702610937 nanoseconds
#
#         HOST_TIME: 148714751973 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148702610950 nanoseconds
#
#         HOST_TIME: 148714664963 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148703424450 nanoseconds
#
#         HOST_TIME: 148709122546 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148704763075 nanoseconds
#
#         HOST_TIME: 148709206713 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148714734912 nanoseconds
#
#         HOST_TIME: 148719503067 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148716033425 nanoseconds
#
#         HOST_TIME: 148721967181 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148724727525 nanoseconds
#
#         HOST_TIME: 148731033223 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148728642375 nanoseconds
#
#         HOST_TIME: 148734333275 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148734719987 nanoseconds
#
#         HOST_TIME: 148740458744 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148741251350 nanoseconds
#
#         HOST_TIME: 148745307546 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148744712425 nanoseconds
#
#         HOST_TIME: 148748670202 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148753860325 nanoseconds
#
#         HOST_TIME: 148760446921 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148754704900 nanoseconds
#
#         HOST_TIME: 148760469681 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148764697700 nanoseconds
#
#         HOST_TIME: 148768875827 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148766469275 nanoseconds
#
#         HOST_TIME: 148770902338 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148774690225 nanoseconds
#
#         HOST_TIME: 148778963588 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148779078237 nanoseconds
#
#         HOST_TIME: 148784162129 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148784682600 nanoseconds
#
#         HOST_TIME: 148789935723 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148791687212 nanoseconds
#
#         HOST_TIME: 148797114056 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148794675200 nanoseconds
#
#         HOST_TIME: 148799000150 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148802610937 nanoseconds
#
#         HOST_TIME: 148814714973 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148802610950 nanoseconds
#
#         HOST_TIME: 148814561963 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148804296162 nanoseconds
#
#         HOST_TIME: 148809786192 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148804667725 nanoseconds
#
#         HOST_TIME: 148809852338 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148814660275 nanoseconds
#
#         HOST_TIME: 148821715515 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148816905125 nanoseconds
#
#         HOST_TIME: 148823200463 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148824652900 nanoseconds
#
#         HOST_TIME: 148830164890 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148829514112 nanoseconds
#
#         HOST_TIME: 148834570254 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148834645350 nanoseconds
#
#         HOST_TIME: 148839204994 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148842123087 nanoseconds
#
#         HOST_TIME: 148847544004 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148844637900 nanoseconds
#
#         HOST_TIME: 148849385202 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148854630337 nanoseconds
#
#         HOST_TIME: 148859848692 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148854732050 nanoseconds
#
#         HOST_TIME: 148859882702 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148864622925 nanoseconds
#
#         HOST_TIME: 148868889890 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148867341012 nanoseconds
#
#         HOST_TIME: 148872923900 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148874615550 nanoseconds
#
#         HOST_TIME: 148879896504 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148879949975 nanoseconds
#
#         HOST_TIME: 148885735150 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148884608025 nanoseconds
#
#         HOST_TIME: 148889460775 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148892558950 nanoseconds
#
#         HOST_TIME: 148898538171 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148894614000 nanoseconds
#
#         HOST_TIME: 148900512806 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148902610937 nanoseconds
#
#         HOST_TIME: 148914820973 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 148902610950 nanoseconds
#
#         HOST_TIME: 148914621963 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148904593212 nanoseconds
#
#         HOST_TIME: 148911360515 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148905167912 nanoseconds
#
#         HOST_TIME: 148911427963 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148914585637 nanoseconds
#
#         HOST_TIME: 148919559473 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148917776875 nanoseconds
#
#         HOST_TIME: 148924733692 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148924578137 nanoseconds
#
#         HOST_TIME: 148931780723 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148930385850 nanoseconds
#
#         HOST_TIME: 148938390775 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148934570700 nanoseconds
#
#         HOST_TIME: 148940837233 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148942994800 nanoseconds
#
#         HOST_TIME: 148948480463 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148944563275 nanoseconds
#
#         HOST_TIME: 148949686088 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148954555775 nanoseconds
#
#         HOST_TIME: 148959002546 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148955603775 nanoseconds
#
#         HOST_TIME: 148960860254 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148964548387 nanoseconds
#
#         HOST_TIME: 148970271973 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148968212737 nanoseconds
#
#         HOST_TIME: 148973658223 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148974540925 nanoseconds
#
#         HOST_TIME: 148978972858 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148980821712 nanoseconds
#
#         HOST_TIME: 148986553223 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148984533450 nanoseconds
#
#         HOST_TIME: 148989637650 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148993430675 nanoseconds
#
#         HOST_TIME: 148999024942 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 148994526075 nanoseconds
#
#         HOST_TIME: 148999087494 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149002610925 nanoseconds
#
#         HOST_TIME: 149014605963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149002610937 nanoseconds
#
#         HOST_TIME: 149014812973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149004518637 nanoseconds
#
#         HOST_TIME: 149010868275 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149006039637 nanoseconds
#
#         HOST_TIME: 149012058171 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149014511125 nanoseconds
#
#         HOST_TIME: 149018636400 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149018648612 nanoseconds
#
#         HOST_TIME: 149024257233 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149024503550 nanoseconds
#
#         HOST_TIME: 149030788379 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149031257600 nanoseconds
#
#         HOST_TIME: 149037042754 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149034496237 nanoseconds
#
#         HOST_TIME: 149039191244 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149043866537 nanoseconds
#
#         HOST_TIME: 149052721973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149044493437 nanoseconds
#
#         HOST_TIME: 149052785931 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149054481487 nanoseconds
#
#         HOST_TIME: 149060743379 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149056475512 nanoseconds
#
#         HOST_TIME: 149062957390 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149064473687 nanoseconds
#
#         HOST_TIME: 149069413223 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149069084475 nanoseconds
#
#         HOST_TIME: 149075470410 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149074466537 nanoseconds
#
#         HOST_TIME: 149078931192 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149081693462 nanoseconds
#
#         HOST_TIME: 149086754108 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149084458925 nanoseconds
#
#         HOST_TIME: 149089547598 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149094302425 nanoseconds
#
#         HOST_TIME: 149099368900 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149094451675 nanoseconds
#
#         HOST_TIME: 149099443015 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149102610925 nanoseconds
#
#         HOST_TIME: 149114862963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149102610937 nanoseconds
#
#         HOST_TIME: 149114861973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149104444137 nanoseconds
#
#         HOST_TIME: 149111302494 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149106911387 nanoseconds
#
#         HOST_TIME: 149113198588 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149114436825 nanoseconds
#
#         HOST_TIME: 149119844890 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149119520362 nanoseconds
#
#         HOST_TIME: 149126462702 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149124429337 nanoseconds
#
#         HOST_TIME: 149129989160 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149132129312 nanoseconds
#
#         HOST_TIME: 149139906504 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149134421937 nanoseconds
#
#         HOST_TIME: 149143062338 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149144414350 nanoseconds
#
#         HOST_TIME: 149149981921 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149144738300 nanoseconds
#
#         HOST_TIME: 149150142963 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149154406725 nanoseconds
#
#         HOST_TIME: 149159504681 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149157347262 nanoseconds
#
#         HOST_TIME: 149162963431 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149164399400 nanoseconds
#
#         HOST_TIME: 149169478640 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149169956225 nanoseconds
#
#         HOST_TIME: 149175491608 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149174392000 nanoseconds
#
#         HOST_TIME: 149178861244 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149182565175 nanoseconds
#
#         HOST_TIME: 149188103535 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149184384512 nanoseconds
#
#         HOST_TIME: 149189669942 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149194377012 nanoseconds
#
#         HOST_TIME: 149200533796 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149195174175 nanoseconds
#
#         HOST_TIME: 149200677025 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149202610925 nanoseconds
#
#         HOST_TIME: 149214612963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149202610937 nanoseconds
#
#         HOST_TIME: 149214821973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149204369625 nanoseconds
#
#         HOST_TIME: 149210497963 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149207783125 nanoseconds
#
#         HOST_TIME: 149214830463 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149214362287 nanoseconds
#
#         HOST_TIME: 149219959213 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149220392100 nanoseconds
#
#         HOST_TIME: 149227342077 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149224354750 nanoseconds
#
#         HOST_TIME: 149233665515 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149233001062 nanoseconds
#
#         HOST_TIME: 149241036140 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149234359812 nanoseconds
#
#         HOST_TIME: 149242355879 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149244339937 nanoseconds
#
#         HOST_TIME: 149249237754 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149245610025 nanoseconds
#
#         HOST_TIME: 149251760567 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149254332537 nanoseconds
#
#         HOST_TIME: 149258497806 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149258219000 nanoseconds
#
#         HOST_TIME: 149264168483 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149264324875 nanoseconds
#
#         HOST_TIME: 149269397963 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149270827962 nanoseconds
#
#         HOST_TIME: 149275588015 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149274317525 nanoseconds
#
#         HOST_TIME: 149278670358 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149283436950 nanoseconds
#
#         HOST_TIME: 149289401400 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149284310200 nanoseconds
#
#         HOST_TIME: 149289461192 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149294302687 nanoseconds
#
#         HOST_TIME: 149300514942 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149296045925 nanoseconds
#
#         HOST_TIME: 149301519265 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149302610925 nanoseconds
#
#         HOST_TIME: 149314719963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149302610937 nanoseconds
#
#         HOST_TIME: 149314811973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149304295275 nanoseconds
#
#         HOST_TIME: 149309187077 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149308654875 nanoseconds
#
#         HOST_TIME: 149314132858 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149314287887 nanoseconds
#
#         HOST_TIME: 149319073275 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149321263862 nanoseconds
#
#         HOST_TIME: 149329526504 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149324280362 nanoseconds
#
#         HOST_TIME: 149332229212 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149333872812 nanoseconds
#
#         HOST_TIME: 149344443223 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149334273062 nanoseconds
#
#         HOST_TIME: 149344502702 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149344265525 nanoseconds
#
#         HOST_TIME: 149351936921 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149346481775 nanoseconds
#
#         HOST_TIME: 149353428431 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149354258200 nanoseconds
#
#         HOST_TIME: 149358861869 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149359090750 nanoseconds
#
#         HOST_TIME: 149363951817 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149364250662 nanoseconds
#
#         HOST_TIME: 149369677285 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149371699737 nanoseconds
#
#         HOST_TIME: 149378309890 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149374243225 nanoseconds
#
#         HOST_TIME: 149379929629 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149384250937 nanoseconds
#
#         HOST_TIME: 149388769629 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149384308700 nanoseconds
#
#         HOST_TIME: 149390118119 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149394228412 nanoseconds
#
#         HOST_TIME: 149399214577 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149396917687 nanoseconds
#
#         HOST_TIME: 149402673640 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149402610925 nanoseconds
#
#         HOST_TIME: 149414616963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149402610937 nanoseconds
#
#         HOST_TIME: 149414816973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149404221050 nanoseconds
#
#         HOST_TIME: 149412689212 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149409526637 nanoseconds
#
#         HOST_TIME: 149418902181 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149414213587 nanoseconds
#
#         HOST_TIME: 149422350098 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149422135637 nanoseconds
#
#         HOST_TIME: 149429249004 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149424206137 nanoseconds
#
#         HOST_TIME: 149431276087 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149434198737 nanoseconds
#
#         HOST_TIME: 149442327077 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149434744587 nanoseconds
#
#         HOST_TIME: 149442385931 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149444191262 nanoseconds
#
#         HOST_TIME: 149449314265 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149447353562 nanoseconds
#
#         HOST_TIME: 149452835931 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149454183862 nanoseconds
#
#         HOST_TIME: 149459753587 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149459962525 nanoseconds
#
#         HOST_TIME: 149465494525 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149464176475 nanoseconds
#
#         HOST_TIME: 149469188223 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149472571487 nanoseconds
#
#         HOST_TIME: 149478062962 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149474169137 nanoseconds
#
#         HOST_TIME: 149480457129 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149484161700 nanoseconds
#
#         HOST_TIME: 149490596921 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149485180462 nanoseconds
#
#         HOST_TIME: 149492189525 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149494154375 nanoseconds
#
#         HOST_TIME: 149498790775 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149497789425 nanoseconds
#
#         HOST_TIME: 149503098692 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149502610925 nanoseconds
#
#         HOST_TIME: 149514622963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149502610937 nanoseconds
#
#         HOST_TIME: 149514819973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149504146850 nanoseconds
#
#         HOST_TIME: 149510798848 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149510398412 nanoseconds
#
#         HOST_TIME: 149517342442 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149514139412 nanoseconds
#
#         HOST_TIME: 149518720931 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149523007375 nanoseconds
#
#         HOST_TIME: 149527811712 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149524132025 nanoseconds
#
#         HOST_TIME: 149529622129 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149534124600 nanoseconds
#
#         HOST_TIME: 149542980619 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149535616362 nanoseconds
#
#         HOST_TIME: 149543160358 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149544117137 nanoseconds
#
#         HOST_TIME: 149549570619 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149548225312 nanoseconds
#
#         HOST_TIME: 149553896244 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149554109800 nanoseconds
#
#         HOST_TIME: 149558856608 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149560834275 nanoseconds
#
#         HOST_TIME: 149566110358 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149564102375 nanoseconds
#
#         HOST_TIME: 149569808900 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149573443275 nanoseconds
#
#         HOST_TIME: 149578333431 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149574094850 nanoseconds
#
#         HOST_TIME: 149578396192 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149584087562 nanoseconds
#
#         HOST_TIME: 149589075202 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149586052250 nanoseconds
#
#         HOST_TIME: 149591059837 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149594080100 nanoseconds
#
#         HOST_TIME: 149599309160 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149598661200 nanoseconds
#
#         HOST_TIME: 149604757858 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149602610925 nanoseconds
#
#         HOST_TIME: 149614623963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149602610937 nanoseconds
#
#         HOST_TIME: 149614821973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149604072675 nanoseconds
#
#         HOST_TIME: 149609857858 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149611270162 nanoseconds
#
#         HOST_TIME: 149618665046 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149614065300 nanoseconds
#
#         HOST_TIME: 149620769421 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149623879150 nanoseconds
#
#         HOST_TIME: 149632014942 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149624057887 nanoseconds
#
#         HOST_TIME: 149632083014 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149634050500 nanoseconds
#
#         HOST_TIME: 149641745410 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149636488125 nanoseconds
#
#         HOST_TIME: 149643937285 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149644042937 nanoseconds
#
#         HOST_TIME: 149648822858 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149649097100 nanoseconds
#
#         HOST_TIME: 149655277910 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149654035625 nanoseconds
#
#         HOST_TIME: 149660185775 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149661706062 nanoseconds
#
#         HOST_TIME: 149667019733 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149664028175 nanoseconds
#
#         HOST_TIME: 149668548744 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149674020812 nanoseconds
#
#         HOST_TIME: 149680121035 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149674315050 nanoseconds
#
#         HOST_TIME: 149680191139 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149684013300 nanoseconds
#
#         HOST_TIME: 149688951608 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149686924012 nanoseconds
#
#         HOST_TIME: 149692420619 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149694006037 nanoseconds
#
#         HOST_TIME: 149700402702 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149699532975 nanoseconds
#
#         HOST_TIME: 149705817025 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149702610925 nanoseconds
#
#         HOST_TIME: 149714616963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149702610937 nanoseconds
#
#         HOST_TIME: 149714780973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149703998575 nanoseconds
#
#         HOST_TIME: 149711688171 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149712141962 nanoseconds
#
#         HOST_TIME: 149717876087 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149713991350 nanoseconds
#
#         HOST_TIME: 149719704577 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149724001912 nanoseconds
#
#         HOST_TIME: 149729741973 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149724750950 nanoseconds
#
#         HOST_TIME: 149732665827 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149733976500 nanoseconds
#
#         HOST_TIME: 149740912754 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149737359912 nanoseconds
#
#         HOST_TIME: 149742626816 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149743969125 nanoseconds
#
#         HOST_TIME: 149749789473 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149749968887 nanoseconds
#
#         HOST_TIME: 149755120827 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149753961650 nanoseconds
#
#         HOST_TIME: 149758300514 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149762577862 nanoseconds
#
#         HOST_TIME: 149768603327 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149763954350 nanoseconds
#
#         HOST_TIME: 149769839889 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149773946875 nanoseconds
#
#         HOST_TIME: 149779187806 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149775186837 nanoseconds
#
#         HOST_TIME: 149780684994 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149783939562 nanoseconds
#
#         HOST_TIME: 149789714004 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149787795812 nanoseconds
#
#         HOST_TIME: 149792757806 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149793931962 nanoseconds
#
#         HOST_TIME: 149797580150 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149800404787 nanoseconds
#
#         HOST_TIME: 149804624785 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149802610925 nanoseconds
#
#         HOST_TIME: 149815679963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149802610937 nanoseconds
#
#         HOST_TIME: 149815678973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149803924687 nanoseconds
#
#         HOST_TIME: 149807878327 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149813013775 nanoseconds
#
#         HOST_TIME: 149818892129 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149813917312 nanoseconds
#
#         HOST_TIME: 149818905775 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149823909825 nanoseconds
#
#         HOST_TIME: 149828992389 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149825622737 nanoseconds
#
#         HOST_TIME: 149830959994 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149833902487 nanoseconds
#
#         HOST_TIME: 149838424212 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149838231737 nanoseconds
#
#         HOST_TIME: 149843393796 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149843895162 nanoseconds
#
#         HOST_TIME: 149848366191 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149850840700 nanoseconds
#
#         HOST_TIME: 149854954941 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149853887562 nanoseconds
#
#         HOST_TIME: 149856720619 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149863449675 nanoseconds
#
#         HOST_TIME: 149869002129 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149863880250 nanoseconds
#
#         HOST_TIME: 149869081504 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149873872787 nanoseconds
#
#         HOST_TIME: 149879776191 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149876058650 nanoseconds
#
#         HOST_TIME: 149881855566 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149883865587 nanoseconds
#
#         HOST_TIME: 149888813900 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149888667625 nanoseconds
#
#         HOST_TIME: 149893951764 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149893858262 nanoseconds
#
#         HOST_TIME: 149899461660 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149901276612 nanoseconds
#
#         HOST_TIME: 149906725150 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149902610925 nanoseconds
#
#         HOST_TIME: 149914730963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 149902610937 nanoseconds
#
#         HOST_TIME: 149914729973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149903850725 nanoseconds
#
#         HOST_TIME: 149908304212 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149913843437 nanoseconds
#
#         HOST_TIME: 149919854889 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149913885575 nanoseconds
#
#         HOST_TIME: 149919913275 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149923835850 nanoseconds
#
#         HOST_TIME: 149930670150 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149926494562 nanoseconds
#
#         HOST_TIME: 149932729473 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149933828612 nanoseconds
#
#         HOST_TIME: 149940598900 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149939103562 nanoseconds
#
#         HOST_TIME: 149945641608 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149943820975 nanoseconds
#
#         HOST_TIME: 149948690983 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149951712525 nanoseconds
#
#         HOST_TIME: 149956145254 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149953813700 nanoseconds
#
#         HOST_TIME: 149957860671 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149963806187 nanoseconds
#
#         HOST_TIME: 149968415150 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149964321512 nanoseconds
#
#         HOST_TIME: 149969756764 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149973798987 nanoseconds
#
#         HOST_TIME: 149979055410 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 149976930487 nanoseconds
#
# ...
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159247087200 nanoseconds
#
#         HOST_TIME: 159253115980 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159257080050 nanoseconds
#
#         HOST_TIME: 159261664417 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159257251725 nanoseconds
#
#         HOST_TIME: 159261728896 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159267073012 nanoseconds
#
#         HOST_TIME: 159272265146 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159269861062 nanoseconds
#
#         HOST_TIME: 159274103896 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159277065875 nanoseconds
#
#         HOST_TIME: 159281348011 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159282470400 nanoseconds
#
#         HOST_TIME: 159286762802 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159287058787 nanoseconds
#
#         HOST_TIME: 159291804313 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159295079750 nanoseconds
#
#         HOST_TIME: 159299967698 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159297051687 nanoseconds
#
#         HOST_TIME: 159301381917 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159302610925 nanoseconds
#
#         HOST_TIME: 159314888963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159302610937 nanoseconds
#
#         HOST_TIME: 159315990973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159307044725 nanoseconds
#
#         HOST_TIME: 159311609052 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159307689062 nanoseconds
#
#         HOST_TIME: 159311624417 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159317037462 nanoseconds
#
#         HOST_TIME: 159321831709 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159320298412 nanoseconds
#
#         HOST_TIME: 159325767698 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159327030475 nanoseconds
#
#         HOST_TIME: 159334653688 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159332907750 nanoseconds
#
#         HOST_TIME: 159341746709 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159337023362 nanoseconds
#
#         HOST_TIME: 159344001813 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159345517100 nanoseconds
#
#         HOST_TIME: 159351536865 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159347016212 nanoseconds
#
#         HOST_TIME: 159351709313 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159357009125 nanoseconds
#
#         HOST_TIME: 159362503844 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159358126425 nanoseconds
#
#         HOST_TIME: 159364403167 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159367002075 nanoseconds
#
#         HOST_TIME: 159371515198 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159370735762 nanoseconds
#
#         HOST_TIME: 159377121500 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159376994925 nanoseconds
#
#         HOST_TIME: 159383147334 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159383345112 nanoseconds
#
#         HOST_TIME: 159388497438 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159386987750 nanoseconds
#
#         HOST_TIME: 159392242594 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159395954450 nanoseconds
#
#         HOST_TIME: 159400710823 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159396980762 nanoseconds
#
#         HOST_TIME: 159402539938 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159402610925 nanoseconds
#
#         HOST_TIME: 159415116963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159402610937 nanoseconds
#
#         HOST_TIME: 159415886973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159406973675 nanoseconds
#
#         HOST_TIME: 159414248167 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159408563787 nanoseconds
#
#         HOST_TIME: 159415743844 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159416966662 nanoseconds
#
#         HOST_TIME: 159421933740 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159421173150 nanoseconds
#
#         HOST_TIME: 159427947334 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159426959650 nanoseconds
#
#         HOST_TIME: 159434072542 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159433782475 nanoseconds
#
#         HOST_TIME: 159438868688 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159436952575 nanoseconds
#
#         HOST_TIME: 159445165927 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159446391825 nanoseconds
#
#         HOST_TIME: 159452960563 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159446945475 nanoseconds
#
#         HOST_TIME: 159453024990 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159456938387 nanoseconds
#
#         HOST_TIME: 159461911552 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159459001162 nanoseconds
#
#         HOST_TIME: 159465454104 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159466931225 nanoseconds
#
#         HOST_TIME: 159472620563 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159471610512 nanoseconds
#
#         HOST_TIME: 159475680875 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159476924200 nanoseconds
#
#         HOST_TIME: 159481235094 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159484219862 nanoseconds
#
#         HOST_TIME: 159490279990 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159486916912 nanoseconds
#
#         HOST_TIME: 159492250979 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159496829225 nanoseconds
#
#         HOST_TIME: 159502981396 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159496909887 nanoseconds
#
#         HOST_TIME: 159502932177 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159502610925 nanoseconds
#
#         HOST_TIME: 159515072963 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159502610937 nanoseconds
#
#         HOST_TIME: 159515905973 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159506902962 nanoseconds
#
#         HOST_TIME: 159514714000 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159509438550 nanoseconds
#
#         HOST_TIME: 159517691761 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159516895887 nanoseconds
#
#         HOST_TIME: 159521567542 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159522047900 nanoseconds
#
#         HOST_TIME: 159527879261 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159526888925 nanoseconds
#
#         HOST_TIME: 159533759834 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159534657250 nanoseconds
#
#         HOST_TIME: 159542651344 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159536881637 nanoseconds
#
#         HOST_TIME: 159542886136 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159546874650 nanoseconds
#
#         HOST_TIME: 159551504834 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159547266600 nanoseconds
#
#         HOST_TIME: 159551561657 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159556867412 nanoseconds
#
#         HOST_TIME: 159563347229 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159559875950 nanoseconds
#
#         HOST_TIME: 159564951240 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159566860262 nanoseconds
#
#         HOST_TIME: 159572389834 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159572485275 nanoseconds
#
#         HOST_TIME: 159577486084 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159576853412 nanoseconds
#
#         HOST_TIME: 159581922959 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159585094637 nanoseconds
#
#         HOST_TIME: 159590269990 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159586846412 nanoseconds
#
#         HOST_TIME: 159592447802 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159596839350 nanoseconds
#
#         HOST_TIME: 159602940406 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159597703975 nanoseconds
#
#         HOST_TIME: 159604391344 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159602610937 nanoseconds
#
#         HOST_TIME: 159615661973 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159602610950 nanoseconds
#
#         HOST_TIME: 159615069963 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159606832200 nanoseconds
#
#         HOST_TIME: 159613916552 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159610313337 nanoseconds
#
#         HOST_TIME: 159617828740 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159616825175 nanoseconds
#
#         HOST_TIME: 159623034573 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159622922687 nanoseconds
#
#         HOST_TIME: 159629798584 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159626818062 nanoseconds
#
#         HOST_TIME: 159633882646 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159635532062 nanoseconds
#
#         HOST_TIME: 159641069834 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159636811062 nanoseconds
#
#         HOST_TIME: 159642554104 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159646810425 nanoseconds
#
#         HOST_TIME: 159651923792 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159648141400 nanoseconds
#
#         HOST_TIME: 159653448636 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159656796737 nanoseconds
#
#         HOST_TIME: 159662167698 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159660750750 nanoseconds
#
#         HOST_TIME: 159665489990 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159666789762 nanoseconds
#
#         HOST_TIME: 159671133584 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159673360087 nanoseconds
#
#         HOST_TIME: 159679601761 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159676782625 nanoseconds
#
#         HOST_TIME: 159684403740 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159685969450 nanoseconds
#
#         HOST_TIME: 159691270511 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159686779200 nanoseconds
#
#         HOST_TIME: 159691329052 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159696768325 nanoseconds
#
#         HOST_TIME: 159701964625 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159698578800 nanoseconds
#
#         HOST_TIME: 159703476917 nanoseconds
#
#
# obtain data from camera-slam-left of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159702610937 nanoseconds
#
#         HOST_TIME: 159715620973 nanoseconds
#
#
# obtain data from camera-slam-right of type SensorDataType.IMAGE with
#
#         DEVICE_TIME: 159702610950 nanoseconds
#
#         HOST_TIME: 159715120963 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159706761250 nanoseconds
#
#         HOST_TIME: 159713961240 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159711188175 nanoseconds
#
#         HOST_TIME: 159717404677 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159716754262 nanoseconds
#
#         HOST_TIME: 159721262542 nanoseconds
#
#
# obtain data from imu-left of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159723797537 nanoseconds
#
#         HOST_TIME: 159730290511 nanoseconds
#
#
# obtain data from imu-right of type SensorDataType.IMU with
#
#         DEVICE_TIME: 159726747100 nanoseconds
#
#         HOST_TIME: 159735353219 nanoseconds

# %% [markdown]
# # Random access data
# Goal
# - Access data from a stream randomly using a data index or a timestamp
#
# Key learnings
# - Sensor data can be obtained through index within the range of [0, number of data for this stream_id)
#
#   - `get_sensor_data_by_index(stream_id, index)`
#   - `get_image_data_by_index(stream_id, index)`
#   - Access other sensor data by index interface is available in core/python/VrsDataProviderPyBind.h
#
# - `TimeQueryOptions` has three options: `TimeQueryOptions.BEFORE`, `TimeQueryOptions.AFTER`, `TimeQueryOptions.CLOSEST`
# - Query through index will provide the exact data vs query through a timestamp that is not exact, data nearby will be omitted base on `TimeQueryOptions`

# %%
sensor_name = "camera-slam-right"
sensor_stream_id = provider.get_stream_id_from_label(sensor_name)

# get all image data by index
num_data = provider.get_num_data(sensor_stream_id)

for index in range(0, num_data):
    image_data = provider.get_image_data_by_index(sensor_stream_id, index)
    print(
        f"Get image: {index} with timestamp {image_data[1].capture_timestamp_ns}"
    )
# Out:
# Get image: 0 with timestamp 148502610950
# Get image: 1 with timestamp 148602610950
# Get image: 2 with timestamp 148702610950
# Get image: 3 with timestamp 148802610950
# Get image: 4 with timestamp 148902610950
# Get image: 5 with timestamp 149002610925
# Get image: 6 with timestamp 149102610925
# Get image: 7 with timestamp 149202610925
# Get image: 8 with timestamp 149302610925
# Get image: 9 with timestamp 149402610925
# Get image: 10 with timestamp 149502610925
# Get image: 11 with timestamp 149602610925
# Get image: 12 with timestamp 149702610925
# Get image: 13 with timestamp 149802610925
# Get image: 14 with timestamp 149902610925
# Get image: 15 with timestamp 150002610950
# Get image: 16 with timestamp 150102610925
# Get image: 17 with timestamp 150202610937
# Get image: 18 with timestamp 150302610925
# Get image: 19 with timestamp 150402610925
# Get image: 20 with timestamp 150502610950
# Get image: 21 with timestamp 150602610950
# Get image: 22 with timestamp 150702610950
# Get image: 23 with timestamp 150802610950
# Get image: 24 with timestamp 150902610925
# Get image: 25 with timestamp 151002610925
# Get image: 26 with timestamp 151102610937
# Get image: 27 with timestamp 151202610925
# Get image: 28 with timestamp 151302610925
# Get image: 29 with timestamp 151402610925
# Get image: 30 with timestamp 151502610925
# Get image: 31 with timestamp 151602610950
# Get image: 32 with timestamp 151702610925
# Get image: 33 with timestamp 151802610925
# Get image: 34 with timestamp 151902610925
# Get image: 35 with timestamp 152002610925
# Get image: 36 with timestamp 152102610925
# Get image: 37 with timestamp 152202610925
# Get image: 38 with timestamp 152302610925
# Get image: 39 with timestamp 152402610925
# Get image: 40 with timestamp 152502610925
# Get image: 41 with timestamp 152602610925
# Get image: 42 with timestamp 152702610937
# Get image: 43 with timestamp 152802610950
# Get image: 44 with timestamp 152902610950
# Get image: 45 with timestamp 153002610925
# Get image: 46 with timestamp 153102610925
# Get image: 47 with timestamp 153202610937
# Get image: 48 with timestamp 153302610925
# Get image: 49 with timestamp 153402610925
# Get image: 50 with timestamp 153502610925
# Get image: 51 with timestamp 153602610925
# Get image: 52 with timestamp 153702610950
# Get image: 53 with timestamp 153802610925
# Get image: 54 with timestamp 153902610925
# Get image: 55 with timestamp 154002610937
# Get image: 56 with timestamp 154102610925
# Get image: 57 with timestamp 154202610925
# Get image: 58 with timestamp 154302610925
# Get image: 59 with timestamp 154402610925
# Get image: 60 with timestamp 154502610925
# Get image: 61 with timestamp 154602610950
# Get image: 62 with timestamp 154702610925
# Get image: 63 with timestamp 154802610925
# Get image: 64 with timestamp 154902610950
# Get image: 65 with timestamp 155002610925
# Get image: 66 with timestamp 155102610925
# Get image: 67 with timestamp 155202610950
# Get image: 68 with timestamp 155302610937
# Get image: 69 with timestamp 155402610925
# Get image: 70 with timestamp 155502610950
# Get image: 71 with timestamp 155602610925
# Get image: 72 with timestamp 155702610950
# Get image: 73 with timestamp 155802610950
# Get image: 74 with timestamp 155902610950
# Get image: 75 with timestamp 156002610950
# Get image: 76 with timestamp 156102610950
# Get image: 77 with timestamp 156202610950
# Get image: 78 with timestamp 156302610950
# Get image: 79 with timestamp 156402610925
# Get image: 80 with timestamp 156502610950
# Get image: 81 with timestamp 156602610937
# Get image: 82 with timestamp 156702610950
# Get image: 83 with timestamp 156802610925
# Get image: 84 with timestamp 156902610925
# Get image: 85 with timestamp 157002610925
# Get image: 86 with timestamp 157102610925
# Get image: 87 with timestamp 157202610925
# Get image: 88 with timestamp 157302610950
# Get image: 89 with timestamp 157402610925
# Get image: 90 with timestamp 157502610925
# Get image: 91 with timestamp 157602610950
# Get image: 92 with timestamp 157702610925
# Get image: 93 with timestamp 157802610925
# Get image: 94 with timestamp 157902610925
# Get image: 95 with timestamp 158002610950
# Get image: 96 with timestamp 158102610925
# Get image: 97 with timestamp 158202610925
# Get image: 98 with timestamp 158302610925
# Get image: 99 with timestamp 158402610950
# Get image: 100 with timestamp 158502610950
# Get image: 101 with timestamp 158602610950
# Get image: 102 with timestamp 158702610937
# Get image: 103 with timestamp 158802610950
# Get image: 104 with timestamp 158902610925
# Get image: 105 with timestamp 159002610937
# Get image: 106 with timestamp 159102610937
# Get image: 107 with timestamp 159202610925
# Get image: 108 with timestamp 159302610925
# Get image: 109 with timestamp 159402610925
# Get image: 110 with timestamp 159502610925
# Get image: 111 with timestamp 159602610950
# Get image: 112 with timestamp 159702610950
# Get image: 113 with timestamp 159802610937
# Get image: 114 with timestamp 159902610925
# Get image: 115 with timestamp 160002610937
# Get image: 116 with timestamp 160102610950
# Get image: 117 with timestamp 160202610925
# Get image: 118 with timestamp 160302610925
# Get image: 119 with timestamp 160402610937
# Get image: 120 with timestamp 160502610950
# Get image: 121 with timestamp 160602610925
# Get image: 122 with timestamp 160702610937

# %% [markdown]
# ### Sensor data can be obtained by timestamp (nanoseconds)
# * Get stream time range `get_first_time_ns` and `get_last_time_ns`
# * Specify timedomain: `TimeDomain.DEVICE_TIME` (default)
# * Query data by queryTime
#   * `TimeQueryOptions.BEFORE` (default): sensor_dataTime <= queryTime
#   * `TimeQueryOptions.AFTER` : sensor_dataTime >= queryTime
#   * `TimeQueryOptions.CLOSEST` : sensor_dataTime closest to queryTime

# %%
time_domain = TimeDomain.DEVICE_TIME  # query data based on DEVICE_TIME
option = TimeQueryOptions.CLOSEST # get data whose time [in TimeDomain] is CLOSEST to query time

start_time = provider.get_first_time_ns(sensor_stream_id, time_domain)
end_time = provider.get_last_time_ns(sensor_stream_id, time_domain)

for time in range(start_time, end_time, int(1e7)):
    image_data = provider.get_image_data_by_time_ns(
        sensor_stream_id, time, time_domain, option
    )
    print(
# %% [markdown]
# ### Get sensor data configuration

# %%
def image_config_example(config):
    print(f"device_type {config.device_type}")
    print(f"device_version {config.device_version}")
    print(f"device_serial {config.device_serial}")
    print(f"sensor_serial {config.sensor_serial}")
    print(f"nominal_rate_hz {config.nominal_rate_hz}")
    print(f"image_width {config.image_width}")
    print(f"image_height {config.image_height}")
    print(f"pixel_format {config.pixel_format}")

# %%
config = provider.get_image_configuration(sensor_stream_id)
image_config_example(config)
# Out:
# device_type Aria
# device_version 49619610009200070
# device_serial 1WM093702F1204
# sensor_serial 0072510f1b210405050000130a0f0001
# nominal_rate_hz 10.0
# image_width 640
# image_height 480
# pixel_format 0

# %% [markdown]
# # Calibration examples
# Goal:
# - Obtain camera extrinsics and intrinsics
# - Learn to project a 3D point to camera frame
#
# Key learnings
# - Get calibration for different sensors using sensor labels
# - Learn how to use extrinsics/intrinsics to project a 3D points to a given camera
# - Reference frame convention

# %%
device_calib = provider.get_device_calibration()
all_sensor_labels = device_calib.get_all_labels()
print(f"device calibration contains calibrations for the following sensors \n {all_sensor_labels}")
# Out:
# device calibration contains calibrations for the following sensors
#  ['baro0', 'camera-et-left', 'camera-et-right', 'camera-rgb', 'camera-slam-left', 'camera-slam-right', 'imu-left', 'imu-right', 'mag0', 'mic0', 'mic1', 'mic2', 'mic3', 'mic4', 'mic5', 'mic6']

# %% [markdown]
# ### Project a 3D point to camera frame
#
# In this section we will learn how to retrieve calibration data and how to use it.
# Aria calibration is defined by two objects: one defining the intrinsics (`rgb_calib.project` and `rgb_calib.unproject`) and one defining the extrinsics as a SE3 pose (`device_calib.get_transform_device_sensor(sensor_label`).
#
# Intrinsics can be used to project a 3d point to the image plane or un-project a 2d point as a bearing vector. Extrinsics are used to set the camera in world coordinates at a given rotation and position in space.
#
# ### Reference frame convention
#
# > `transform_sensor1_sensor3` = `transform_sensor1_sensor2` * `transform_sensor2_sensor3` \
# > `point_in_sensor`: 3D point measured from sensor's reference frame \
# > `point_in_sensor` = `transform_sensor1_sensor` * `point_in_sensor`
#
# Device Frame: `device_calib.get_origin_label() = camera-slam-left`\
# Sensor extrinsics: `device_calib.get_transform_device_sensor(sensor_label)`

# %%
camera_name = "camera-rgb"
transform_device_camera = device_calib.get_transform_device_sensor(camera_name).to_matrix()
transform_camera_device = np.linalg.inv(transform_device_camera)
print(f"Device calibration origin label {device_calib.get_origin_label()}")
print(f"{camera_name} has extrinsics of \n {transform_device_camera}")

rgb_calib = device_calib.get_camera_calib("camera-rgb")
if rgb_calib is not None:
    # project a 3D point in device frame [camera-slam-left] to rgb camera
    point_in_device = np.array([0, 0, 10])
    point_in_camera = (
        np.matmul(transform_camera_device[0:3,0:3], point_in_device.transpose())
        + transform_camera_device[0:3,3]
    )

    maybe_pixel = rgb_calib.project(point_in_camera)
    if maybe_pixel is not None:
        print(
            f"Get pixel {maybe_pixel} within image of size {rgb_calib.get_image_size()}"
        )
# Out:
# Device calibration origin label camera-slam-left
# camera-rgb has extrinsics of
#  [[ 0.99422189 -0.05585578  0.09166768 -0.00400587]
#  [ 0.10103185  0.77543844 -0.62328788 -0.0118698 ]
#  [-0.03626841  0.62894781  0.77660109 -0.00441815]
#  [ 0.          0.          0.          1.        ]]
# Get pixel [ 687.61725368 1175.44508842] within image of size [1408 1408]

# %% [markdown]
# ### Get calibration data for other sensors
# Aria is a multimodal capture device, each sensors calibration can be retrieved using the same interface. Only EyeTracking (`get_aria_et_camera_calib()`) and Audio calibration (`get_aria_microphone_calib()`) is a bit different since we have multiple sensors that share the same stream_id.

# %%
et_calib = device_calib.get_aria_et_camera_calib()
if et_calib is not None:
    print(f"Camera {et_calib[0].get_label()} has image size {et_calib[0].get_image_size()}")
    print(f"Camera {et_calib[1].get_label()} has image size {et_calib[1].get_image_size()}")

imu_calib = device_calib.get_imu_calib("imu-left")
if imu_calib is not None:
    print(f"{imu_calib.get_label()} has extrinsics transform_Device_Imu:\n {imu_calib.get_transform_device_imu().to_matrix3x4()}")
# Out:
# Camera camera-et-left has image size [320 240]
# Camera camera-et-right has image size [320 240]
# imu-left has extrinsics transform_Device_Imu:
#  [[-1.48646016e-02  9.96264599e-01 -8.50640439e-02  4.34745119e-04]
#  [ 9.99746423e-01  1.33693777e-02 -1.81204016e-02 -4.03922506e-05]
#  [-1.69154613e-02 -8.53118262e-02 -9.96210700e-01 -6.41339470e-03]]

# %% [markdown]
# ### Undistort an image
# You can remove distortions in an image in three steps.
#
# First, use the provider to access the image and the camera calibration of the stream. Then create a "linear" spherical camera model with `get_spherical_camera_calibration`. The function allows you to specify the image size as well as focal length of the model, assuming principal point is at the image center. Finally, apply `distort_by_calibration` function to distort the image.

# %%
# input: retrieve image as a numpy array
sensor_name = "camera-rgb"
sensor_stream_id = provider.get_stream_id_from_label(sensor_name)
image_data = provider.get_image_data_by_index(sensor_stream_id, 0)
image_array = image_data[0].to_numpy_array()
# input: retrieve image distortion
device_calib = provider.get_device_calibration()
src_calib = device_calib.get_camera_calib(sensor_name)

# create output calibration: a linear model of image size 512x512 and focal length 150
# Invisible pixels are shown as black.
dst_calib = calibration.get_linear_camera_calibration(512, 512, 150, camera_name)

# distort image
rectified_array = calibration.distort_by_calibration(image_array, dst_calib, src_calib, InterpolationMethod.BILINEAR)

# visualize input and results
plt.figure()
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
fig.suptitle(f"Image undistortion (focal length = {dst_calib.get_focal_lengths()})")

axes[0].imshow(image_array, cmap="gray", vmin=0, vmax=255)
axes[0].title.set_text(f"sensor image ({sensor_name})")
axes[0].tick_params(left=False, right=False, labelleft=False, labelbottom=False, bottom=False)
axes[1].imshow(rectified_array, cmap="gray", vmin=0, vmax=255)
axes[1].title.set_text(f"undistorted image ({sensor_name})")
axes[1].tick_params(left=False, right=False, labelleft=False, labelbottom=False, bottom=False)
plt.show()

# %% [markdown]
# Note the rectified image shows a circular area of visible pixels. If you want the entire rectified image to be covered by pixels, you can increase the magnification.
